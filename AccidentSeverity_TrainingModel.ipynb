# %%
#getting started
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow as tf

# %%
data = pd.read_csv('US_Accidents_March23.csv', nrows=400000)

# %%
data
# Out:
#               ID   Source  Severity           Start_Time             End_Time  \
# 0            A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1            A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2            A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3            A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4            A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# ...          ...      ...       ...                  ...                  ...
# 399995  A-400008  Source2         3  2017-04-25 12:15:27  2017-04-25 12:49:00
# 399996  A-400009  Source2         3  2017-04-25 12:13:06  2017-04-25 12:44:00
# 399997  A-400010  Source2         2  2017-04-25 12:14:47  2017-04-25 12:48:00
# 399998  A-400011  Source2         2  2017-04-25 12:32:34  2017-04-25 13:03:00
# 399999  A-400012  Source2         2  2017-04-25 12:44:45  2017-04-25 13:14:25
#
#         Start_Lat   Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0       39.865147  -84.058723      NaN      NaN          0.01  ...      False
# 1       39.928059  -82.831184      NaN      NaN          0.01  ...      False
# 2       39.063148  -84.032608      NaN      NaN          0.01  ...      False
# 3       39.747753  -84.205582      NaN      NaN          0.01  ...      False
# 4       39.627781  -84.188354      NaN      NaN          0.01  ...      False
# ...           ...         ...      ...      ...           ...  ...        ...
# 399995  37.516037 -121.940689      NaN      NaN          0.01  ...      False
# 399996  37.458626 -121.924133      NaN      NaN          0.01  ...      False
# 399997  37.355961 -121.868294      NaN      NaN          0.01  ...      False
# 399998  37.452118 -122.126907      NaN      NaN          0.01  ...      False
# 399999  38.626274 -122.878220      NaN      NaN          0.01  ...      False
#
#        Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0        False  False           False          False        False
# 1        False  False           False          False        False
# 2        False  False           False           True        False
# 3        False  False           False          False        False
# 4        False  False           False           True        False
# ...        ...    ...             ...            ...          ...
# 399995   False  False           False          False        False
# 399996   False  False           False          False        False
# 399997   False  False           False          False        False
# 399998   False  False           False          False        False
# 399999   False  False           False          False        False
#
#        Sunrise_Sunset Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0               Night          Night             Night                 Night
# 1               Night          Night             Night                   Day
# 2               Night          Night               Day                   Day
# 3               Night            Day               Day                   Day
# 4                 Day            Day               Day                   Day
# ...               ...            ...               ...                   ...
# 399995            Day            Day               Day                   Day
# 399996            Day            Day               Day                   Day
# 399997            Day            Day               Day                   Day
# 399998            Day            Day               Day                   Day
# 399999            Day            Day               Day                   Day
#
# [400000 rows x 46 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     400000 non-null  object
#  1   Source                 400000 non-null  object
#  2   Severity               400000 non-null  int64
#  3   Start_Time             400000 non-null  object
#  4   End_Time               400000 non-null  object
#  5   Start_Lat              400000 non-null  float64
#  6   Start_Lng              400000 non-null  float64
#  7   End_Lat                0 non-null       float64
#  8   End_Lng                0 non-null       float64
#  9   Distance(mi)           400000 non-null  float64
#  10  Description            400000 non-null  object
#  11  Street                 400000 non-null  object
#  12  City                   399981 non-null  object
#  13  County                 400000 non-null  object
#  14  State                  400000 non-null  object
#  15  Zipcode                399957 non-null  object
#  16  Country                400000 non-null  object
#  17  Timezone               399957 non-null  object
#  18  Airport_Code           399956 non-null  object
#  19  Weather_Timestamp      396791 non-null  object
#  20  Temperature(F)         394085 non-null  float64
#  21  Wind_Chill(F)          59095 non-null   float64
#  22  Humidity(%)            393491 non-null  float64
#  23  Pressure(in)           395353 non-null  float64
#  24  Visibility(mi)         391221 non-null  float64
#  25  Wind_Direction         396770 non-null  object
#  26  Wind_Speed(mph)        325829 non-null  float64
#  27  Precipitation(in)      42045 non-null   float64
#  28  Weather_Condition      391792 non-null  object
#  29  Amenity                400000 non-null  bool
#  30  Bump                   400000 non-null  bool
#  31  Crossing               400000 non-null  bool
#  32  Give_Way               400000 non-null  bool
#  33  Junction               400000 non-null  bool
#  34  No_Exit                400000 non-null  bool
#  35  Railway                400000 non-null  bool
#  36  Roundabout             400000 non-null  bool
#  37  Station                400000 non-null  bool
#  38  Stop                   400000 non-null  bool
#  39  Traffic_Calming        400000 non-null  bool
#  40  Traffic_Signal         400000 non-null  bool
#  41  Turning_Loop           400000 non-null  bool
#  42  Sunrise_Sunset         399981 non-null  object
#  43  Civil_Twilight         399981 non-null  object
#  44  Nautical_Twilight      399981 non-null  object
#  45  Astronomical_Twilight  399981 non-null  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 105.7+ MB

# %%
#dealing with missing values
data.isna().mean()
# Out:
# ID                       0.000000
# Source                   0.000000
# Severity                 0.000000
# Start_Time               0.000000
# End_Time                 0.000000
# Start_Lat                0.000000
# Start_Lng                0.000000
# End_Lat                  1.000000
# End_Lng                  1.000000
# Distance(mi)             0.000000
# Description              0.000000
# Street                   0.000000
# City                     0.000048
# County                   0.000000
# State                    0.000000
# Zipcode                  0.000107
# Country                  0.000000
# Timezone                 0.000107
# Airport_Code             0.000110
# Weather_Timestamp        0.008023
# Temperature(F)           0.014788
# Wind_Chill(F)            0.852263
# Humidity(%)              0.016272
# Pressure(in)             0.011617
# Visibility(mi)           0.021948
# Wind_Direction           0.008075
# Wind_Speed(mph)          0.185427
# Precipitation(in)        0.894887
# Weather_Condition        0.020520
# Amenity                  0.000000
# Bump                     0.000000
# Crossing                 0.000000
# Give_Way                 0.000000
# Junction                 0.000000
# No_Exit                  0.000000
# Railway                  0.000000
# Roundabout               0.000000
# Station                  0.000000
# Stop                     0.000000
# Traffic_Calming          0.000000
# Traffic_Signal           0.000000
# Turning_Loop             0.000000
# Sunrise_Sunset           0.000048
# Civil_Twilight           0.000048
# Nautical_Twilight        0.000048
# Astronomical_Twilight    0.000048
# dtype: float64

# %%
null_columns = ['End_Lat', 'End_Lng', 'Wind_Chill(F)', 'Precipitation(in)']

data = data.drop(null_columns, axis=1)

# %%
data.isna().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                  400000
# End_Lng                  400000
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                         19
# County                        0
# State                         0
# Zipcode                      43
# Country                       0
# Timezone                     43
# Airport_Code                 44
# Weather_Timestamp          3209
# Temperature(F)             5915
# Wind_Chill(F)            340905
# Humidity(%)                6509
# Pressure(in)               4647
# Visibility(mi)             8779
# Wind_Direction             3230
# Wind_Speed(mph)           74171
# Precipitation(in)        357955
# Weather_Condition          8208
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# No_Exit                       0
# Railway                       0
# Roundabout                    0
# Station                       0
# Stop                          0
# Traffic_Calming               0
# Traffic_Signal                0
# Turning_Loop                  0
# Sunrise_Sunset               19
# Civil_Twilight               19
# Nautical_Twilight            19
# Astronomical_Twilight        19
# dtype: int64

# %%
data = data.dropna(axis=0).reset_index(drop=True)

# %%
print("Total missing values:", data.isna().sum().sum())
# Out:
# Total missing values: 0

# %%
data
# Out:
#               ID   Source  Severity           Start_Time             End_Time  \
# 0            A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 1            A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 2            A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 3            A-6  Source2         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 4            A-7  Source2         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# ...          ...      ...       ...                  ...                  ...
# 320980  A-400007  Source2         2  2017-04-25 12:08:49  2017-04-25 12:38:27
# 320981  A-400008  Source2         3  2017-04-25 12:15:27  2017-04-25 12:49:00
# 320982  A-400009  Source2         3  2017-04-25 12:13:06  2017-04-25 12:44:00
# 320983  A-400010  Source2         2  2017-04-25 12:14:47  2017-04-25 12:48:00
# 320984  A-400011  Source2         2  2017-04-25 12:32:34  2017-04-25 13:03:00
#
#         Start_Lat   Start_Lng  Distance(mi)  \
# 0       39.063148  -84.032608          0.01
# 1       39.747753  -84.205582          0.01
# 2       39.627781  -84.188354          0.01
# 3       40.100590  -82.925194          0.01
# 4       39.758274  -84.230507          0.00
# ...           ...         ...           ...
# 320980  37.352116 -122.059219          0.01
# 320981  37.516037 -121.940689          0.01
# 320982  37.458626 -121.924133          0.01
# 320983  37.355961 -121.868294          0.01
# 320984  37.452118 -122.126907          0.01
#
#                                               Description  \
# 0       Accident on OH-32 State Route 32 Westbound at ...
# 1       Accident on I-75 Southbound at Exits 52 52B US...
# 2       Accident on McEwen Rd at OH-725 Miamisburg Cen...
# 3       Accident on I-270 Outerbelt Northbound near Ex...
# 4       Accident on Oakridge Dr at Woodward Ave. Expec...
# ...                                                   ...
# 320980           Accident on Fremont Ave at Bernardo Ave.
# 320981  Right hand shoulder blocked due to accident on...
# 320982  Accident on I-880 Southbound at Exit 10 Dixon ...
# 320983  Right hand shoulder blocked due to accident on...
# 320984  Right hand shoulder blocked due to accident on...
#
#                            Street  ... Roundabout Station   Stop  \
# 0                  State Route 32  ...      False   False  False
# 1                          I-75 S  ...      False   False  False
# 2       Miamisburg Centerville Rd  ...      False   False  False
# 3                  Westerville Rd  ...      False   False  False
# 4                  N Woodward Ave  ...      False   False  False
# ...                           ...  ...        ...     ...    ...
# 320980             S Bernardo Ave  ...      False   False  False
# 320981                    I-680 S  ...      False   False  False
# 320982               Nimitz Fwy S  ...      False   False  False
# 320983             Bayshore Fwy S  ...      False   False  False
# 320984             Bayshore Fwy S  ...      False   False  False
#
#        Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0                False           True        False          Night
# 1                False          False        False          Night
# 2                False           True        False            Day
# 3                False          False        False            Day
# 4                False          False        False            Day
# ...                ...            ...          ...            ...
# 320980           False           True        False            Day
# 320981           False          False        False            Day
# 320982           False          False        False            Day
# 320983           False          False        False            Day
# 320984           False          False        False            Day
#
#        Civil_Twilight  Nautical_Twilight  Astronomical_Twilight
# 0               Night                Day                    Day
# 1                 Day                Day                    Day
# 2                 Day                Day                    Day
# 3                 Day                Day                    Day
# 4                 Day                Day                    Day
# ...               ...                ...                    ...
# 320980            Day                Day                    Day
# 320981            Day                Day                    Day
# 320982            Day                Day                    Day
# 320983            Day                Day                    Day
# 320984            Day                Day                    Day
#
# [320985 rows x 42 columns]

# %%
#unnecessary columns
{column: len(data[column].unique()) for column in data.columns if data.dtypes[column] == 'object'}
# Out:
# {'ID': 320985,
#  'Source': 2,
#  'Start_Time': 316633,
#  'End_Time': 314443,
#  'Description': 236516,
#  'Street': 36216,
#  'City': 4024,
#  'County': 548,
#  'State': 28,
#  'Zipcode': 57076,
#  'Country': 1,
#  'Timezone': 4,
#  'Airport_Code': 638,
#  'Weather_Timestamp': 78674,
#  'Wind_Direction': 23,
#  'Weather_Condition': 67,
#  'Sunrise_Sunset': 2,
#  'Civil_Twilight': 2,
#  'Nautical_Twilight': 2,
#  'Astronomical_Twilight': 2}

# %%
unneeded_columns = ['ID', 'Description', 'Street', 'City', 'Zipcode', 'Country']

data = data.drop(unneeded_columns, axis=1)

# %%
data
# Out:
#          Source  Severity           Start_Time             End_Time  \
# 0       Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 1       Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 2       Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 3       Source2         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 4       Source2         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# ...         ...       ...                  ...                  ...
# 320980  Source2         2  2017-04-25 12:08:49  2017-04-25 12:38:27
# 320981  Source2         3  2017-04-25 12:15:27  2017-04-25 12:49:00
# 320982  Source2         3  2017-04-25 12:13:06  2017-04-25 12:44:00
# 320983  Source2         2  2017-04-25 12:14:47  2017-04-25 12:48:00
# 320984  Source2         2  2017-04-25 12:32:34  2017-04-25 13:03:00
#
#         Start_Lat   Start_Lng  Distance(mi)       County State    Timezone  \
# 0       39.063148  -84.032608          0.01     Clermont    OH  US/Eastern
# 1       39.747753  -84.205582          0.01   Montgomery    OH  US/Eastern
# 2       39.627781  -84.188354          0.01   Montgomery    OH  US/Eastern
# 3       40.100590  -82.925194          0.01     Franklin    OH  US/Eastern
# 4       39.758274  -84.230507          0.00   Montgomery    OH  US/Eastern
# ...           ...         ...           ...          ...   ...         ...
# 320980  37.352116 -122.059219          0.01  Santa Clara    CA  US/Pacific
# 320981  37.516037 -121.940689          0.01      Alameda    CA  US/Pacific
# 320982  37.458626 -121.924133          0.01      Alameda    CA  US/Pacific
# 320983  37.355961 -121.868294          0.01  Santa Clara    CA  US/Pacific
# 320984  37.452118 -122.126907          0.01  Santa Clara    CA  US/Pacific
#
#         ... Roundabout Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0       ...      False   False  False            False            True
# 1       ...      False   False  False            False           False
# 2       ...      False   False  False            False            True
# 3       ...      False   False  False            False           False
# 4       ...      False   False  False            False           False
# ...     ...        ...     ...    ...              ...             ...
# 320980  ...      False   False  False            False            True
# 320981  ...      False   False  False            False           False
# 320982  ...      False   False  False            False           False
# 320983  ...      False   False  False            False           False
# 320984  ...      False   False  False            False           False
#
#         Turning_Loop Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0              False          Night           Night               Day
# 1              False          Night             Day               Day
# 2              False            Day             Day               Day
# 3              False            Day             Day               Day
# 4              False            Day             Day               Day
# ...              ...            ...             ...               ...
# 320980         False            Day             Day               Day
# 320981         False            Day             Day               Day
# 320982         False            Day             Day               Day
# 320983         False            Day             Day               Day
# 320984         False            Day             Day               Day
#
#         Astronomical_Twilight
# 0                         Day
# 1                         Day
# 2                         Day
# 3                         Day
# 4                         Day
# ...                       ...
# 320980                    Day
# 320981                    Day
# 320982                    Day
# 320983                    Day
# 320984                    Day
#
# [320985 rows x 36 columns]

# %%
def get_years(df, column):
    return df[column].apply(lambda date: date[0:4])

def get_months(df, column):
    return df[column].apply(lambda date: date[5:7])

# %%
data['Start_Time_Month'] = get_months(data, 'Start_Time')
data['Start_Time_Year'] = get_years(data, 'Start_Time')

data['End_Time_Month'] = get_months(data, 'End_Time')
data['End_Time_Year'] = get_years(data, 'End_Time')

data['Weather_Timestamp_Month'] = get_months(data, 'Weather_Timestamp')
data['Weather_Timestamp_Year'] = get_years(data, 'Weather_Timestamp')


data = data.drop(['Start_Time', 'End_Time', 'Weather_Timestamp'], axis=1)

# %%
data
# Out:
#          Source  Severity  Start_Lat   Start_Lng  Distance(mi)       County  \
# 0       Source2         2  39.063148  -84.032608          0.01     Clermont
# 1       Source2         3  39.747753  -84.205582          0.01   Montgomery
# 2       Source2         2  39.627781  -84.188354          0.01   Montgomery
# 3       Source2         3  40.100590  -82.925194          0.01     Franklin
# 4       Source2         2  39.758274  -84.230507          0.00   Montgomery
# ...         ...       ...        ...         ...           ...          ...
# 320980  Source2         2  37.352116 -122.059219          0.01  Santa Clara
# 320981  Source2         3  37.516037 -121.940689          0.01      Alameda
# 320982  Source2         3  37.458626 -121.924133          0.01      Alameda
# 320983  Source2         2  37.355961 -121.868294          0.01  Santa Clara
# 320984  Source2         2  37.452118 -122.126907          0.01  Santa Clara
#
#        State    Timezone Airport_Code  Temperature(F)  ...  Sunrise_Sunset  \
# 0         OH  US/Eastern         KI69            36.0  ...           Night
# 1         OH  US/Eastern         KDAY            35.1  ...           Night
# 2         OH  US/Eastern         KMGY            36.0  ...             Day
# 3         OH  US/Eastern         KCMH            37.9  ...             Day
# 4         OH  US/Eastern         KDAY            34.0  ...             Day
# ...      ...         ...          ...             ...  ...             ...
# 320980    CA  US/Pacific         KNUQ            63.0  ...             Day
# 320981    CA  US/Pacific         KNUQ            63.0  ...             Day
# 320982    CA  US/Pacific         KPAO            64.4  ...             Day
# 320983    CA  US/Pacific         KRHV            64.4  ...             Day
# 320984    CA  US/Pacific         KPAO            64.4  ...             Day
#
#         Civil_Twilight  Nautical_Twilight Astronomical_Twilight  \
# 0                Night                Day                   Day
# 1                  Day                Day                   Day
# 2                  Day                Day                   Day
# 3                  Day                Day                   Day
# 4                  Day                Day                   Day
# ...                ...                ...                   ...
# 320980             Day                Day                   Day
# 320981             Day                Day                   Day
# 320982             Day                Day                   Day
# 320983             Day                Day                   Day
# 320984             Day                Day                   Day
#
#         Start_Time_Month Start_Time_Year  End_Time_Month  End_Time_Year  \
# 0                     02            2016              02           2016
# 1                     02            2016              02           2016
# 2                     02            2016              02           2016
# 3                     02            2016              02           2016
# 4                     02            2016              02           2016
# ...                  ...             ...             ...            ...
# 320980                04            2017              04           2017
# 320981                04            2017              04           2017
# 320982                04            2017              04           2017
# 320983                04            2017              04           2017
# 320984                04            2017              04           2017
#
#         Weather_Timestamp_Month  Weather_Timestamp_Year
# 0                            02                    2016
# 1                            02                    2016
# 2                            02                    2016
# 3                            02                    2016
# 4                            02                    2016
# ...                         ...                     ...
# 320980                       04                    2017
# 320981                       04                    2017
# 320982                       04                    2017
# 320983                       04                    2017
# 320984                       04                    2017
#
# [320985 rows x 39 columns]

# %%
#encoding
def onehot_encode(df, columns, prefixes):
    df = df.copy()
    for column, prefix in zip(columns, prefixes):
        dummies = pd.get_dummies(df[column], prefix=prefix)
        df = pd.concat([df, dummies], axis=1)
        df = df.drop(column, axis=1)
    return df

# %%
{column: len(data[column].unique()) for column in data.columns if data.dtypes[column] == 'object'}
# Out:
# {'Source': 2,
#  'County': 548,
#  'State': 28,
#  'Timezone': 4,
#  'Airport_Code': 638,
#  'Wind_Direction': 23,
#  'Weather_Condition': 67,
#  'Sunrise_Sunset': 2,
#  'Civil_Twilight': 2,
#  'Nautical_Twilight': 2,
#  'Astronomical_Twilight': 2,
#  'Start_Time_Month': 12,
#  'Start_Time_Year': 2,
#  'End_Time_Month': 12,
#  'End_Time_Year': 2,
#  'Weather_Timestamp_Month': 12,
#  'Weather_Timestamp_Year': 2}

# %%
data = onehot_encode(
    data,
    columns=['County', 'State', 'Timezone', 'Airport_Code', 'Wind_Direction', 'Weather_Condition'],
    prefixes=['CO', 'ST', 'TZ', 'AC', 'WD', 'WC']
)

# %%
data
# Out:
#          Source  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0       Source2         2  39.063148  -84.032608          0.01
# 1       Source2         3  39.747753  -84.205582          0.01
# 2       Source2         2  39.627781  -84.188354          0.01
# 3       Source2         3  40.100590  -82.925194          0.01
# 4       Source2         2  39.758274  -84.230507          0.00
# ...         ...       ...        ...         ...           ...
# 320980  Source2         2  37.352116 -122.059219          0.01
# 320981  Source2         3  37.516037 -121.940689          0.01
# 320982  Source2         3  37.458626 -121.924133          0.01
# 320983  Source2         2  37.355961 -121.868294          0.01
# 320984  Source2         2  37.452118 -122.126907          0.01
#
#         Temperature(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0                 36.0        100.0         29.67            10.0
# 1                 35.1         96.0         29.64             9.0
# 2                 36.0         89.0         29.65             6.0
# 3                 37.9         97.0         29.63             7.0
# 4                 34.0        100.0         29.66             7.0
# ...                ...          ...           ...             ...
# 320980            63.0         58.0         30.12            10.0
# 320981            63.0         58.0         30.12            10.0
# 320982            64.4         59.0         30.11            10.0
# 320983            64.4         49.0         30.13            10.0
# 320984            64.4         59.0         30.11            10.0
#
#         Wind_Speed(mph)  ...  WC_Snow  WC_Snow Grains  WC_Snow Showers  \
# 0                   3.5  ...    False           False            False
# 1                   4.6  ...    False           False            False
# 2                   3.5  ...    False           False            False
# 3                   3.5  ...    False           False            False
# 4                   3.5  ...    False           False            False
# ...                 ...  ...      ...             ...              ...
# 320980             16.1  ...    False           False            False
# 320981             16.1  ...    False           False            False
# 320982             16.1  ...    False           False            False
# 320983              9.2  ...    False           False            False
# 320984             16.1  ...    False           False            False
#
#         WC_Squalls  WC_T-Storm  WC_Thunder  WC_Thunder in the Vicinity  \
# 0            False       False       False                       False
# 1            False       False       False                       False
# 2            False       False       False                       False
# 3            False       False       False                       False
# 4            False       False       False                       False
# ...            ...         ...         ...                         ...
# 320980       False       False       False                       False
# 320981       False       False       False                       False
# 320982       False       False       False                       False
# 320983       False       False       False                       False
# 320984       False       False       False                       False
#
#         WC_Thunderstorm  WC_Thunderstorms and Rain  WC_Widespread Dust
# 0                 False                      False               False
# 1                 False                      False               False
# 2                 False                      False               False
# 3                 False                      False               False
# 4                 False                      False               False
# ...                 ...                        ...                 ...
# 320980            False                      False               False
# 320981            False                      False               False
# 320982            False                      False               False
# 320983            False                      False               False
# 320984            False                      False               False
#
# [320985 rows x 1341 columns]

# %%
def get_binary_column(df, column):
    if column == 'Source':
        return df[column].apply(lambda x: 1 if x == 'MapQuest' else 0)
    else:
        return df[column].apply(lambda x: 1 if x == 'Day' else 0)

# %%
data['Source'] = get_binary_column(data, 'Source')

data['Sunrise_Sunset'] = get_binary_column(data, 'Sunrise_Sunset')
data['Civil_Twilight'] = get_binary_column(data, 'Civil_Twilight')
data['Nautical_Twilight'] = get_binary_column(data, 'Nautical_Twilight')
data['Astronomical_Twilight'] = get_binary_column(data, 'Astronomical_Twilight')

# %%
data
# Out:
#         Source  Severity  Start_Lat   Start_Lng  Distance(mi)  Temperature(F)  \
# 0            0         2  39.063148  -84.032608          0.01            36.0
# 1            0         3  39.747753  -84.205582          0.01            35.1
# 2            0         2  39.627781  -84.188354          0.01            36.0
# 3            0         3  40.100590  -82.925194          0.01            37.9
# 4            0         2  39.758274  -84.230507          0.00            34.0
# ...        ...       ...        ...         ...           ...             ...
# 320980       0         2  37.352116 -122.059219          0.01            63.0
# 320981       0         3  37.516037 -121.940689          0.01            63.0
# 320982       0         3  37.458626 -121.924133          0.01            64.4
# 320983       0         2  37.355961 -121.868294          0.01            64.4
# 320984       0         2  37.452118 -122.126907          0.01            64.4
#
#         Humidity(%)  Pressure(in)  Visibility(mi)  Wind_Speed(mph)  ...  \
# 0             100.0         29.67            10.0              3.5  ...
# 1              96.0         29.64             9.0              4.6  ...
# 2              89.0         29.65             6.0              3.5  ...
# 3              97.0         29.63             7.0              3.5  ...
# 4             100.0         29.66             7.0              3.5  ...
# ...             ...           ...             ...              ...  ...
# 320980         58.0         30.12            10.0             16.1  ...
# 320981         58.0         30.12            10.0             16.1  ...
# 320982         59.0         30.11            10.0             16.1  ...
# 320983         49.0         30.13            10.0              9.2  ...
# 320984         59.0         30.11            10.0             16.1  ...
#
#         WC_Snow  WC_Snow Grains  WC_Snow Showers  WC_Squalls  WC_T-Storm  \
# 0         False           False            False       False       False
# 1         False           False            False       False       False
# 2         False           False            False       False       False
# 3         False           False            False       False       False
# 4         False           False            False       False       False
# ...         ...             ...              ...         ...         ...
# 320980    False           False            False       False       False
# 320981    False           False            False       False       False
# 320982    False           False            False       False       False
# 320983    False           False            False       False       False
# 320984    False           False            False       False       False
#
#         WC_Thunder  WC_Thunder in the Vicinity  WC_Thunderstorm  \
# 0            False                       False            False
# 1            False                       False            False
# 2            False                       False            False
# 3            False                       False            False
# 4            False                       False            False
# ...            ...                         ...              ...
# 320980       False                       False            False
# 320981       False                       False            False
# 320982       False                       False            False
# 320983       False                       False            False
# 320984       False                       False            False
#
#         WC_Thunderstorms and Rain  WC_Widespread Dust
# 0                           False               False
# 1                           False               False
# 2                           False               False
# 3                           False               False
# 4                           False               False
# ...                           ...                 ...
# 320980                      False               False
# 320981                      False               False
# 320982                      False               False
# 320983                      False               False
# 320984                      False               False
#
# [320985 rows x 1341 columns]

# %%
#splitting and scaling 
y = data['Severity'].copy()
X = data.drop('Severity', axis=1).copy()

# %%
y.unique()
# Out:
# array([2, 3, 1, 4], dtype=int64)

# %%
y = y - 1

# %%
X = X.astype(float)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=100)

# %%
#training
X.shape
# Out:
# (320985, 1340)

# %%
inputs = tf.keras.Input(shape=(X.shape[1],))
x = tf.keras.layers.Dense(64, activation='relu')(inputs)
x = tf.keras.layers.Dense(64, activation='relu')(x)
outputs = tf.keras.layers.Dense(4, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

batch_size = 32
epochs = 20

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.ReduceLROnPlateau(),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/20
# 5618/5618 [==============================] - 25s 4ms/step - loss: 0.4711 - accuracy: 0.7761 - val_loss: 0.4599 - val_accuracy: 0.7810 - lr: 0.0010
# Epoch 2/20
# 5618/5618 [==============================] - 16s 3ms/step - loss: 0.4390 - accuracy: 0.7893 - val_loss: 0.4520 - val_accuracy: 0.7827 - lr: 0.0010
# Epoch 3/20
# 5618/5618 [==============================] - 16s 3ms/step - loss: 0.4300 - accuracy: 0.7944 - val_loss: 0.4473 - val_accuracy: 0.7861 - lr: 0.0010
# Epoch 4/20
# 5618/5618 [==============================] - 17s 3ms/step - loss: 0.4250 - accuracy: 0.7964 - val_loss: 0.4432 - val_accuracy: 0.7878 - lr: 0.0010
# Epoch 5/20
# 5618/5618 [==============================] - 16s 3ms/step - loss: 0.4215 - accuracy: 0.7987 - val_loss: 0.4438 - val_accuracy: 0.7892 - lr: 0.0010
# Epoch 6/20
# 5618/5618 [==============================] - 19s 3ms/step - loss: 0.4185 - accuracy: 0.7996 - val_loss: 0.4456 - val_accuracy: 0.7913 - lr: 0.0010
# Epoch 7/20
# 5618/5618 [==============================] - 16s 3ms/step - loss: 0.4156 - accuracy: 0.8008 - val_loss: 0.4453 - val_accuracy: 0.7888 - lr: 0.0010

# %%
print("Test Accuracy:", model.evaluate(X_test, y_test, verbose=0)[1])
# Out:
# Test Accuracy: 0.7897524237632751
